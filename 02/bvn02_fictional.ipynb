# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Introduction:
#
# This exercise was inspired by this [page](http://chrisalbon.com/python/)
#
# Special thanks to: https://github.com/chrisalbon for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

# %%
army = pd.DataFrame(raw_data,columns=['regiment','compady','deaths','battles','size','veterans','raediness','armored','deserters','origin'])

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army = army.set_index('origin')

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army['veterans']
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['regiment', 'compady', 'deaths', 'battles', 'size', 'veterans',
#        'raediness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[['Maine', 'Alaska'], ['deaths', 'size', 'deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[3:7,3:6]
# Out:
#          battles  size  veterans
# origin
# Florida        2  1400        26
# Maine          4  1592        73
# Iowa           7  1006        37
# Alaska         8   987       949

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
army.iloc[4:,:]
# Out:
#             regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Maine       Dragoons     NaN      43        4  1592        73       NaN
# Iowa        Dragoons     NaN     234        7  1006        37       NaN
# Alaska      Dragoons     NaN     523        8   987       949       NaN
# Washington  Dragoons     NaN      62        3   849        48       NaN
# Oregon        Scouts     NaN      62        4   973        48       NaN
# Wyoming       Scouts     NaN      73        7  1005       435       NaN
# Louisana      Scouts     NaN      37        8  1099        63       NaN
# Georgia       Scouts     NaN      35        9  1523       345       NaN
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
army.iloc[:4,:]
# Out:
#               regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Arizona     Nighthawks     NaN     523        5  1045         1       NaN
# California  Nighthawks     NaN      52       42   957         5       NaN
# Texas       Nighthawks     NaN      25        2  1099        62       NaN
# Florida     Nighthawks     NaN     616        2  1400        26       NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[:,3:8]
# Out:
#             battles  size  veterans raediness  armored
# origin
# Arizona           5  1045         1       NaN        1
# California       42   957         5       NaN        0
# Texas             2  1099        62       NaN        1
# Florida           2  1400        26       NaN        1
# Maine             4  1592        73       NaN        0
# Iowa              7  1006        37       NaN        1
# Alaska            8   987       949       NaN        0
# Washington        3   849        48       NaN        1
# Oregon            4   973        48       NaN        0
# Wyoming           7  1005       435       NaN        0
# Louisana          8  1099        63       NaN        1
# Georgia           9  1523       345       NaN        1

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
army[army['deaths']>50]
# Out:
#               regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Arizona     Nighthawks     NaN     523        5  1045         1       NaN
# California  Nighthawks     NaN      52       42   957         5       NaN
# Florida     Nighthawks     NaN     616        2  1400        26       NaN
# Iowa          Dragoons     NaN     234        7  1006        37       NaN
# Alaska        Dragoons     NaN     523        8   987       949       NaN
# Washington    Dragoons     NaN      62        3   849        48       NaN
# Oregon          Scouts     NaN      62        4   973        48       NaN
# Wyoming         Scouts     NaN      73        7  1005       435       NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army[(army['deaths']<50) | (army['deaths']>500)]
# Out:
#             regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Arizona   Nighthawks     NaN     523        5  1045         1       NaN
# Texas     Nighthawks     NaN      25        2  1099        62       NaN
# Florida   Nighthawks     NaN     616        2  1400        26       NaN
# Maine       Dragoons     NaN      43        4  1592        73       NaN
# Alaska      Dragoons     NaN     523        8   987       949       NaN
# Louisana      Scouts     NaN      37        8  1099        63       NaN
# Georgia       Scouts     NaN      35        9  1523       345       NaN
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
army[army['regiment']!='Dragoons']
# Out:
#               regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Arizona     Nighthawks     NaN     523        5  1045         1       NaN
# California  Nighthawks     NaN      52       42   957         5       NaN
# Texas       Nighthawks     NaN      25        2  1099        62       NaN
# Florida     Nighthawks     NaN     616        2  1400        26       NaN
# Oregon          Scouts     NaN      62        4   973        48       NaN
# Wyoming         Scouts     NaN      73        7  1005       435       NaN
# Louisana        Scouts     NaN      37        8  1099        63       NaN
# Georgia         Scouts     NaN      35        9  1523       345       NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
army.loc[['Texas','Arizona'],:]
# Out:
#            regiment compady  deaths  battles  size  veterans raediness  \
# origin
# Texas    Nighthawks     NaN      25        2  1099        62       NaN
# Arizona  Nighthawks     NaN     523        5  1045         1       NaN
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
army.loc['Arizona',:].iloc[2]
# Out:
# 523

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.loc[:,'deaths'].iloc[2]
# Out:
# 25
